# %% [markdown]
# # 머신러닝 회귀모델 실습
# - Kaggle data : https://www.kaggle.com/mustafaali96/weight-height
# - 데이터 컬럼 : Gender, Height, Weight
# - 목표(target) : 사람의 키에 따른 몸무게 예측하기
# - 학습기(Estimator) : LinearRegression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, root_mean_squared_error

# %% [markdown]
# ## 데이터 로딩 및 단위 변경

# %%
# read weight-height dataset
data = "datas_ml/weight-height.csv"
wh_df = pd.read_csv(data)

# %%
wh_df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ### [문제해결] 컬럼 단위를 우리에게 익숙한 값으로 변경하기
# - 키 : inch -> cm, 1inch = 2.54cm
# - 몸무게 : lb(파운트) -> kg, 1lb = 0.4563kg

# %% [markdown]
# #### 방법

# %%
# read weight-height dataset
data = "datas_ml/weight-height.csv"
wh_df = pd.read_csv(data)


# 키 변경하기(inch -> cm)
wh_df["Height"] = wh_df["Height"] * 2.54
wh_df.head()
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  241.893563
# 1   Male  174.706036  162.310473
# 2   Male  188.239668  212.740856
# 3   Male  182.196685  220.042470
# 4   Male  177.499761  206.349801

# %%
# 몸무게 변경하기(lb -> kg)
# 1lb = 0.4563kg 
wh_df["Weight"] = wh_df["Weight"] * 0.4563

wh_df.head()
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  110.376033
# 1   Male  174.706036   74.062269
# 2   Male  188.239668   97.073652
# 3   Male  182.196685  100.405379
# 4   Male  177.499761   94.157414

# %%
wh_df.shape
# Out:
# (10000, 3)

# %% [markdown]
# # 데이터 탐색

# %%
wh_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  str
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), str(1)
# memory usage: 234.5 KB

# %%
#[문제] 기초 통계량 확인
wh_df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean     168.573602     73.665235
# std        9.772721     14.651081
# min      137.828359     29.522668
# 25%      161.304276     61.973777
# 50%      168.447898     73.561459
# 75%      175.702625     85.405454
# max      200.656806    123.196299

# %%
wh_df['Gender'].describe()
# Out:
# count     10000
# unique        2
# top        Male
# freq       5000
# Name: Gender, dtype: object

# %%
# 키와 몸무게 분포 확인
sns.scatterplot(data=wh_df, x = 'Height', y = 'Weight')
plt.show()

# %% [markdown]
# # 1. 키에 따른 몸무게 예측
# ## 학습, 테스트 데이터 준비
# - Feature(x)와 label(y) 데이터 분리

# %%
x = wh_df["Height"] # 입력데이터
y = wh_df["Weight"] # 정답데이터

# %%
y[:5]
# Out:
# 0    110.376033
# 1     74.062269
# 2     97.073652
# 3    100.405379
# 4     94.157414
# Name: Weight, dtype: float64

# %%
type(y)
# Out:
# pandas.Series

# %% [markdown]
# ## 80%는 트레이닝 데이터, 20%는 테스트 데이터로 나누기
# - random_seed 값 주기
# - stratify=y 설정은
#   - target이 classification인 경우
#   - feature가 2개이상 있을 때 사용

# %%
# 학습, 테스트 데이터셋으로 분할
x_train, x_test, y_train, y_test = train_test_split(
    x, y, 
    test_size=0.2, # 분할 비율 8:2
    random_state=10  # 데이터 분할 재현
    )

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((8000,), (2000,), (8000,), (2000,))

# %% [markdown]
# ## 회귀 모델 학습하기
# - 선형회귀(Linear Regression

# %%
# 회귀 모델 알고리즘 객체 생성
model_lr = LinearRegression()

# %%
model_lr
# Out:
# LinearRegression()

# %%
x_train.shape
# Out:
# (8000,)

# %%
# x_train 데이터가 1D 이면 오류 발생함 / X데이터는 2D 여야함
model_lr.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 # x_train 데이터가 1D 이면 오류 발생함
# ----> 2 model_lr.fit(x_train, y_train)
#
# File ~/ml_ex/.venv/lib/python3.12/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File ~/ml_ex/.venv/lib/python3.12/site-packages/sklearn/linear_model/_base.py:681, in LinearRegression.fit(self, X, y, sample_weight)
#     677 n_jobs_ = self.n_jobs
#     679 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 681 X, y = validate_data(
#     682     self,
#     683     X,
#     684     y,
#     685     accept_sparse=accept_sparse,
#     686     y_numeric=True,
#     687     multi_output=True,
#     688     force_writeable=True,
#     689 )
#     691 has_sw = sample_weight is not None
#     692 if has_sw:
#
# File ~/ml_ex/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:3055, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3053         y = check_array(y, input_name="y", **check_y_params)
#    3054     else:
# -> 3055         X, y = check_X_y(X, y, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/ml_ex/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:1327, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1322         estimator_name = _check_estimator_name(estimator)
#    1323     raise ValueError(
#    1324         f"{estimator_name} requires y to be passed, but the target y is None"
#    1325     )
# -> 1327 X = check_array(
#    1328     X,
#    1329     accept_sparse=accept_sparse,
#    1330     accept_large_sparse=accept_large_sparse,
#    1331     dtype=dtype,
#    1332     order=order,
#    1333     copy=copy,
#    1334     force_writeable=force_writeable,
#    1335     ensure_all_finite=ensure_all_finite,
#    1336     ensure_2d=ensure_2d,
#    1337     allow_nd=allow_nd,
#    1338     ensure_min_samples=ensure_min_samples,
#    1339     ensure_min_features=ensure_min_features,
#    1340     estimator=estimator,
#    1341     input_name="X",
#    1342 )
#    1344 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1346 check_consistent_length(X, y)
#
# File ~/ml_ex/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:1073, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1066         else:
#    1067             msg = (
#    1068                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1069                 "Reshape your data either using array.reshape(-1, 1) if "
#    1070                 "your data has a single feature or array.reshape(1, -1) "
#    1071                 "if it contains a single sample."
#    1072             )
# -> 1073         raise ValueError(msg)
#    1075 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1076     raise ValueError(
#    1077         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1078         "Convert your data to numeric values explicitly instead."
#    1079     )
#
# ValueError: Expected a 2-dimensional container but got <class 'pandas.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.

# %%
x_train.shape
# Out:
# (8000,)

# %%
# x는 2차원이어야 함.
x_train_2d = x_train.values.reshape(-1,1)

# %%
type(x_train_2d)
# Out:
# numpy.ndarray

# %%
x_train_2d.shape
# Out:
# (8000, 1)

# %%
# 모델 학습
# model_lr.fit(x_train, y_train)  <-- x_train은 2D 여야함.
model_lr.fit(x_train_2d, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### [tip] feature가 1개인 경우, 학습 및 테스트시 reshape(-1,1)로 차원을 바꿔 주는 이유
# -  학습기는 기본적으로 feature 2개 이상의 input이 들어간다고 가정하고 만들어뒀다.(2차원 array)
# -  현재 키(height)만 있음.(1차원 vector)

# %% [markdown]
# ## 학습 모델 테스트

# %%
#print(type(x_test))
print("테스트 데이터", x_test.values)
print()
print(x_train_2d)
# Out:
# 테스트 데이터 [173.53649028 164.22298414 188.04787828 ... 171.59270539 162.35978704
#  158.54282215]
#
# [[158.38424815]
#  [150.90929264]
#  [163.96639183]
#  ...
#  [172.08583788]
#  [167.17562084]
#  [174.96463993]]

# %%
x_test.values.reshape(-1,1)
# Out:
# array([[173.53649028],
#        [164.22298414],
#        [188.04787828],
#        ...,
#        [171.59270539],
#        [162.35978704],
#        [158.54282215]], shape=(2000, 1))

# %%
# 테스트 데이터에 대한 예측을 수행
y_pred = model_lr.predict(x_test.values.reshape(-1,1))

# %%
# x_test 데이터에 대한 예측 y값
y_pred
# Out:
# array([ 80.48820744,  67.57518835, 100.608002  , ...,  77.79318249,
#         64.99189701,  59.69973961], shape=(2000,))

# %%
y_test[:5]
# Out:
# 937     94.192251
# 9355    67.971504
# 2293    99.389349
# 192     93.037587
# 8675    58.119952
# Name: Weight, dtype: float64

# %%
model_lr.coef_
# Out:
# array([1.38648312])

# %%
model_lr.intercept_
# Out:
# np.float64(-160.11720767437623)

# %% [markdown]
# ## 모델 성능 평가하기

# %% [markdown]
# - MSE(Mean Squared Error)를 측정하기
# - RMSE(Root Mean Squared Error)를 측정하기

# %%
y_test[:5]
# Out:
# 937     94.192251
# 9355    67.971504
# 2293    99.389349
# 192     93.037587
# 8675    58.119952
# Name: Weight, dtype: float64

# %%
# MSE(Mean Squared Error)
MSE = mean_squared_error(y_test, y_pred)

# RMSE(Root Mean Squared Error)를 측정하기

RMSE = root_mean_squared_error(y_test, y_pred)
# RMSE = np.sqrt(MSE)

print('MSE :', MSE)
print('RMSE :', RMSE)

# 결과는 도메인마다 다름
# Out:
# MSE : 31.729201319729576
# RMSE : 5.632867948010993

# %% [markdown]
# ## ML 모델 일반화

# %% [markdown]
# ### [문제해결] 내 몸무게 예측해보기
# - [힌트] x_train 또는 x_test와 같은 shape으로 입력

# %% [markdown]
# 키 165cm -> 몸무게 ?  : [[165]]
# - 방법1 :
# <pre>
#     lr.predict([[165]])
# </pre>
# - 방법2:
# <pre>
#     y_pred2 = lr.predict(np.array([177,185]).reshape(-1,1))
#     y_pred2
# </pre>
# - 방법3:
# <pre>
# my_height1 = pd.Series(172)
# type(my_height1)
# model_lr.predict(my_height1.values.reshape(-1,1))
# </pre>

# %% [markdown]
# ### [문제해결] 내 키와 내 가족 한사람 더추가 해서 예측해보기
# - [힌트] x와 같은 shape으로 입력

# %%
a = model_lr.coef_  # 모델의 가중치(기울기) w 
b = model_lr.intercept_  # 모델의 편향(절편) b
# y_pred = a * x + b
y = a * 165 + b
y
# Out:
# array([68.65250773])

# %%
a
# Out:
# array([1.38648312])

# %%
my_data = [[165]]
y_pred2 = model_lr.predict(my_data)
y_pred2
# Out:
# array([68.65250773])

# %% [markdown]
# ## 예측 결과 시각화

# %%
plt.plot(x_test, y_test, 'o')
plt.plot(x_test, y_pred)
plt.title('Weight and Height Prediction')
plt.show()

# %% [markdown]
# # 키와 성별에 따른 몸무게 예측하기
# - feature 갯수 2개로 학습하기
# - Gender, height 데이터로 linear regression 모델 만들기
# - Gender는 범주형 데이터임 : One Hot Encoding으로 변환하기

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 데이터 로딩 및 가공

# %%
# read weight-height dataset
data = "datas_ml/weight-height.csv"
gwh_df = pd.read_csv(data)
gwh_df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
# 인치, 파운드 -> cm, kg으로 변환
gwh_df["Height"] = gwh_df["Height"] * 2.54
gwh_df["Weight"] = gwh_df["Weight"] * 0.4563
# read weight-height dataset
gwh_df.head()
# Out:
#   Gender      Height      Weight
# 0   Male  187.571423  110.376033
# 1   Male  174.706036   74.062269
# 2   Male  188.239668   97.073652
# 3   Male  182.196685  100.405379
# 4   Male  177.499761   94.157414

# %%
# feature distribution
sns.histplot(data=gwh_df, x="Height", hue="Gender")
plt.figure(figsize=(10,6))

# %% [markdown]
# ## ML을 위한 feature Engineering
# - 범주형 데이터 숫자로 변환 : One Hot Encoding

# %%
gwh_df['Gender'].value_counts()
# Out:
# Gender
# Male      5000
# Female    5000
# Name: count, dtype: int64

# %%
# Gender 컬럼을 숫자로 변환
gwh_df['Gender'] = gwh_df['Gender'].map({"Male": 0, "Female": 1})
gwh_df.head()
# Out:
#    Gender      Height      Weight
# 0       0  187.571423  110.376033
# 1       0  174.706036   74.062269
# 2       0  188.239668   97.073652
# 3       0  182.196685  100.405379
# 4       0  177.499761   94.157414

# %% [markdown]
# ## 학습, 테스트 데이터 준비

# %%
# X = Gender, Height
X = gwh_df.drop(columns='Weight')

# y = Weight
y = gwh_df['Weight']

# %%
X.head()
# Out:
#    Gender      Height
# 0       0  187.571423
# 1       0  174.706036
# 2       0  188.239668
# 3       0  182.196685
# 4       0  177.499761

# %%
# train data : test data로 분할 (8 : 2)

# %%
X_train
# Out:
#       Gender      Height
# 9254       1  155.934775
# 1561       0  189.731998
# 1670       0  174.009850
# 6087       1  167.125690
# 6669       1  170.590986
# ...      ...         ...
# 5734       1  160.908969
# 5191       1  149.508528
# 5390       1  163.386531
# 860        0  175.449210
# 7270       1  171.675653
#
# [8000 rows x 2 columns]

# %% [markdown]
# ## 회귀 모델 학습

# %%
# 학습모델 객체생성, 학습, 테스트
model_lr2 = LinearRegression()
model_lr2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 테스트 및 성능 평가

# %%
y_pred = model_lr2.predict(X_test)
y_pred
# Out:
# array([75.55642225, 84.77185534, 78.14549722, ..., 57.84501902,
#        79.97209066, 48.15240468], shape=(2000,))

# %%
X_test.columns
# Out:
# Index(['Gender', 'Height'], dtype='object')

# %% [markdown]
# ### [문제해결] MSE, RMSE 구하기

# %%
# MSE(Mean Squared Error)를 측정하기
MSE = mean_squared_error(y_test, y_pred)

# RMSE(Root Mean Squared Error)를 측정하기
RMSE = np.sqrt(MSE)

print('MSE :', MSE)
print('RMSE :', RMSE)

# 결과는 도메인마다 다름
# Out:
# MSE : 21.080039418120673
# RMSE : 4.591300405998356

# %% [markdown]
# ## ML 모델 일반화
# ### [문제해결] 키와, 성별 정보로 일반 데이터를 구성하여 예측하기

# %%
my_test = 
my_test
# Out:
# array([[  1, 165]])

# %%
model_lr2.predict(my_test)
# Out:
# C:\Users\magpi\miniconda3\envs\eda_env\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([65.39940251])

# %% [markdown]
# ## 예측 결과 시각화

# %%
X_test[:5]
# Out:
#       Gender      Height
# 6252       1  174.465570
# 4684       0  174.826508
# 1731       0  168.651246
# 4742       0  182.700524
# 4521       0  170.288974

# %%
# 테스트 데이터(X)에 따른 실제 몸무게(y)와 예측 데이터(y^) 그래프 그리기
plt.plot(X_test.loc[:,'Height'], y_test, 'o')  # 실제값 표시
plt.plot(X_test.loc[:,'Height'], y_pred, '^')  # 예측값 표시
plt.title('Weight and Height Prediction')
plt.xlabel('height')
plt.ylabel('weight')
plt.show()
